# %% [markdown]
# <a href="https://colab.research.google.com/github/Joelvdb/BGRacing-cone-detection-computer-vision/blob/main/BGRacing_cone_detection_cv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5

# Install required packages
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17521, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 17521 (delta 9), reused 0 (delta 0), pack-reused 17497 (from 4)
# Receiving objects: 100% (17521/17521), 16.62 MiB | 14.08 MiB/s, done.
# Resolving deltas: 100% (12005/12005), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 102.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 69.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 17.5 MB/s eta 0:00:00
# ...

# %%
data_yaml = """
train: /content/drive/MyDrive/datasets/cone.v2i.yolov5pytorch/train_original/images
val: /content/drive/MyDrive/datasets/cone.v2i.yolov5pytorch/valid_original/images
test: /content/drive/MyDrive/datasets/cone.v2i.yolov5pytorch/test_original/images

nc: 1  # number of classes
names: ['cone']  # class names
"""

with open('data.yaml', 'w') as f:
    f.write(data_yaml)

# %%
# !python /content/yolov5/train.py --workers 8 --img 640 --batch 8 --epochs 50 --data /content/yolov5/data.yaml --weights yolov5s.pt
# Out:
# Streaming output truncated to the last 5000 lines.
#       35/49      2.53G    0.02714     0.0153          0         21        640:  46% 77/169 [00:20<00:22,  4.18it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       35/49      2.53G     0.0273    0.01528          0         22        640:  46% 78/169 [00:20<00:23,  3.90it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       35/49      2.53G    0.02747    0.01523          0         22        640:  47% 79/169 [00:21<00:20,  4.30it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
# !python detect.py \
  --weights runs/train/exp/weights/best.pt \
  --source /content/drive/MyDrive/datasets/fsd1.mp4 \
  --conf 0.25 \
  --img 640 \
  --save-txt \
  --save-conf \
  --project runs/detect \
  --name cone_video \
  --exist-ok
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/datasets/fsd1.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_format=0, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=cone_video, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-423-g567c6646 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/819) /content/drive/MyDrive/datasets/fsd1.mp4: 384x640 5 cones, 27.4ms
# video 1/1 (2/819) /content/drive/MyDrive/datasets/fsd1.mp4: 384x640 5 cones, 7.7ms
# video 1/1 (3/819) /content/drive/MyDrive/datasets/fsd1.mp4: 384x640 6 cones, 7.7ms
# ...
